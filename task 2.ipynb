# %% [markdown]
# # Formatted string for Text

# %%
a = "Kunal" 
print(f"the type of a is {type(a)} and value is '{a}'")

b = "Vishal"
print(f"the type of A is {type(b)} and value is '{b}'")

c = "Sunil"
print(f"the type of A is {type(c)} and value is '{c}'")

d = "suniti"
print(f"the type of A is {type(d)} and value is '{d}'")

e = "sakshi"
print(f"the type of e is {type(e)} and the value is '{e}'")

f = "samiksha"
print(f"the type of f is {type(f)} and the value is '{f}'")

g = "Raj"
print(f"the type of g is {type(g)} and the value is '{g}' ")

h = "raju"
print(f"the type of h is {type(h)} and the value is '{h}' ")

i = "ramesh"
print(f"the type of i is {type(i)} and the value is '{i}' ")

j = "sureh"
print(f"the type of j is {type(j)} and the value is '{j}'")

k = "yash"
print(f"the type of k is {type(k)} and the value is '{k}' ")

l= "luv"
print(f"the type of l is {type(l)} and the value is '{l}' ")

m = "mansi"
print(f"the type of m is {type(m)} and the value is '{m}' ")

n = "nandu"
print(f"the type of n is {type(n)} and the value is '{n}' ")

o = "om"
print(f"the type of o is {type(o)} and the value is '{o}' ")

p = "Aarav"
print(f"The type of p is {type(p)} and the value is '{p}'")

q = "Vivaan"
print(f"The type of q is {type(q)} and the value is '{q}'")

r = "Aditya"
print(f"The type of r is {type(r)} and the value is '{r}'")

s = "Krishna"
print(f"The type of s is {type(s)} and the value is '{s}'")

t = "Arjun"
print(f"The type of t is {type(t)} and the value is '{t}'")

u = "Sai"
print(f"The type of u is {type(u)} and the value is '{u}'")

v = "Reyansh"
print(f"The type of v is {type(v)} and the value is '{v}'")

w = "Ishaan"
print(f"The type of w is {type(w)} and the value is '{w}'")

x = "Om"
print(f"The type of x is {type(x)} and the value is '{x}'")

y = "Laksh"
print(f"The type of y is {type(y)} and the value is '{y}'")

z = "Aryan"
print(f"The type of z is {type(z)} and the value is '{z}'")

thinker = "Atharv"
print(f"The type of thinker is {type(thinker)} and the value is '{thinker}'")

star = "Dhruv"
print(f"The type of star is {type(star)} and the value is '{star}'")

spark = "Vihaan"
print(f"The type of spark is {type(spark)} and the value is '{spark}'")

friend = "Rohan"
print(f"The type of friend is {type(friend)} and the value is '{friend}'")

bright = "Yash"
print(f"The type of bright is {type(bright)} and the value is '{bright}'")

coder = "Kunal"
print(f"The type of coder is {type(coder)} and the value is '{coder}'")

king = "Raj"
print(f"The type of king is {type(king)} and the value is '{king}'")

helper = "Manav"
print(f"The type of helper is {type(helper)} and the value is '{helper}'")

princess = "Saanvi"
print(f"The type of princess is {type(princess)} and the value is '{princess}'")

dreamer = "Aanya"
print(f"The type of dreamer is {type(dreamer)} and the value is '{dreamer}'")

teacher = "Meera"
print(f"The type of teacher is {type(teacher)} and the value is '{teacher}'")

writer = "Kritika"
print(f"The type of writer is {type(writer)} and the value is '{writer}'")

dancer = "Riya"
nickname = "Aarav"
print(f"The type of nickname is {type(nickname)} and the value is '{nickname}'")

boy = "Vivaan"
print(f"The type of boy is {type(boy)} and the value is '{boy}'")

student = "Aditya"
print(f"The type of student is {type(student)} and the value is '{student}'")

devotee = "Krishna"
print(f"The type of devotee is {type(devotee)} and the value is '{devotee}'")

archer = "Arjun"
print(f"The type of archer is {type(archer)} and the value is '{archer}'")

child = "Sai"
print(f"The type of child is {type(child)} and the value is '{child}'")

hero = "Reyansh"
print(f"The type of hero is {type(hero)} and the value is '{hero}'")

brother = "Ishaan"
print(f"The type of brother is {type(brother)} and the value is '{brother}'")

monk = "Kabir"
print(f"The type of monk is {type(monk)} and the value is '{monk}'")

sound = "Om"
print(f"The type of sound is {type(sound)} and the value is '{sound}'")

warrior = "Laksh"
print(f"The type of warrior is {type(warrior)} and the value is '{warrior}'")

leader = "Aryan"
print(f"The type of leader is {type(leader)} and the value is '{leader}'")

thinker = "Atharv"
print(f"The type of thinker is {type(thinker)} and the value is '{thinker}'")

star = "Dhruv"
print(f"The type of star is {type(star)} and the value is '{star}'")

spark = "Vihaan"
print(f"The type of spark is {type(spark)} and the value is '{spark}'")

friend = "Rohan"
print(f"The type of friend is {type(friend)} and the value is '{friend}'")

king = "Raj"
print(f"The type of king is {type(king)} and the value is '{king}'")

helper = "Manav"
print(f"The type of helper is {type(helper)} and the value is '{helper}'")

writer = "Kritika"
print(f"The type of writer is {type(writer)} and the value is '{writer}'")

dancer = "Riya"
print(f"The type of dancer is {type(dancer)} and the value is '{dancer}'")
# Out:
# the type of a is <class 'str'> and value is 'Kunal'
# the type of A is <class 'str'> and value is 'Vishal'
# the type of A is <class 'str'> and value is 'Sunil'
# the type of A is <class 'str'> and value is 'suniti'
# the type of e is <class 'str'> and the value is 'sakshi'
# the type of f is <class 'str'> and the value is 'samiksha'
# the type of g is <class 'str'> and the value is 'Raj'
# the type of h is <class 'str'> and the value is 'raju'
# the type of i is <class 'str'> and the value is 'ramesh'
# the type of j is <class 'str'> and the value is 'sureh'
# the type of k is <class 'str'> and the value is 'yash'
# the type of l is <class 'str'> and the value is 'luv'
# the type of m is <class 'str'> and the value is 'mansi'
# the type of n is <class 'str'> and the value is 'nandu'
# the type of o is <class 'str'> and the value is 'om'
# The type of p is <class 'str'> and the value is 'Aarav'
# The type of q is <class 'str'> and the value is 'Vivaan'
# ...

# %% [markdown]
# # formatted string examples of Int

# %%
a = 56
print(f"the type of a is {type(a)} and value is '{a}'")

b = 62
print(f"the type of A is {type(b)} and value is '{b}'")

c = 12
print(f"the type of A is {type(c)} and value is '{c}'")

d = 30
print(f"the type of A is {type(d)} and value is '{d}'")

e = 45
print(f"the type of e is {type(e)} and the value is '{e}'")

f = 56
print(f"the type of f is {type(f)} and the value is '{f}'")

g = 85
print(f"the type of g is {type(g)} and the value is '{g}' ")

h = 69
print(f"the type of h is {type(h)} and the value is '{h}' ")

i = 70
print(f"the type of i is {type(i)} and the value is '{i}' ")

j = 80
print(f"the type of j is {type(j)} and the value is '{j}'")

k = 90
print(f"the type of k is {type(k)} and the value is '{k}' ")

l= 20
print(f"the type of l is {type(l)} and the value is '{l}' ")

m = 21
print(f"the type of m is {type(m)} and the value is '{m}' ")

n = 22
print(f"the type of n is {type(n)} and the value is '{n}' ")

o = 23
print(f"the type of o is {type(o)} and the value is '{o}' ")

p = 24
print(f"The type of p is {type(p)} and the value is '{p}'")

q = 26
print(f"The type of q is {type(q)} and the value is '{q}'")

r = 45
print(f"The type of r is {type(r)} and the value is '{r}'")

s = 56
print(f"The type of s is {type(s)} and the value is '{s}'")

t = 75
print(f"The type of t is {type(t)} and the value is '{t}'")

u = 78
print(f"The type of u is {type(u)} and the value is '{u}'")

v = 96
print(f"The type of v is {type(v)} and the value is '{v}'")

w = 23
print(f"The type of w is {type(w)} and the value is '{w}'")

x = 10
print(f"The type of x is {type(x)} and the value is '{x}'")

y = 9
print(f"The type of y is {type(y)} and the value is '{y}'")

z = 1
print(f"The type of z is {type(z)} and the value is '{z}'")

roll_number = 101
print(f"The type of roll_number is {type(roll_number)} and the value is {roll_number}")

marks = 95
print(f"The type of marks is {type(marks)} and the value is {marks}")

age = 21
print(f"The type of age is {type(age)} and the value is {age}")

rank = 4
print(f"The type of rank is {type(rank)} and the value is {rank}")

height_cm = 170
print(f"The type of height_cm is {type(height_cm)} and the value is {height_cm}")

year = 2025
print(f"The type of year is {type(year)} and the value is {year}")

price = 499
print(f"The type of price is {type(price)} and the value is {price}")

quantity = 3
print(f"The type of quantity is {type(quantity)} and the value is {quantity}")

day = 19
print(f"The type of day is {type(day)} and the value is {day}")

month = 6
print(f"The type of month is {type(month)} and the value is {month}")

pin_code = 110001
print(f"The type of pin_code is {type(pin_code)} and the value is {pin_code}")

employee_id = 2034
print(f"The type of employee_id is {type(employee_id)} and the value is {employee_id}")

order_id = 9001
print(f"The type of order_id is {type(order_id)} and the value is {order_id}")

ticket_number = 5542
print(f"The type of ticket_number is {type(ticket_number)} and the value is {ticket_number}")

page_count = 230
print(f"The type of page_count is {type(page_count)} and the value is {page_count}")

distance_km = 24
print(f"The type of distance_km is {type(distance_km)} and the value is {distance_km}")

speed = 60
print(f"The type of speed is {type(speed)} and the value is {speed}")

hours = 8
print(f"The type of hours is {type(hours)} and the value is {hours}")

minutes = 45
print(f"The type of minutes is {type(minutes)} and the value is {minutes}")

seconds = 30
print(f"The type of seconds is {type(seconds)} and the value is {seconds}")

print(f"The type of notebooks is {type(notebooks)} and the value is {notebooks}")

errors = 0
print(f"The type of errors is {type(errors)} and the value is {errors}")

attempts = 2
print(f"The type of attempts is {type(attempts)} and the value is {attempts}")

rating = 4
print(f"The type of rating is {type(rating)} and the value is {rating}")

votes = 146
print(f"The type of votes is {type(votes)} and the value is {votes}")

likes = 2100
print(f"The type of likes is {type(likes)} and the value is {likes}")

followers = 350
print(f"The type of followers is {type(followers)} and the value is {followers}")
# Out:
# the type of a is <class 'int'> and value is '56'
# the type of A is <class 'int'> and value is '62'
# the type of A is <class 'int'> and value is '12'
# the type of A is <class 'int'> and value is '30'
# the type of e is <class 'int'> and the value is '45'
# the type of f is <class 'int'> and the value is '56'
# the type of g is <class 'int'> and the value is '85'
# the type of h is <class 'int'> and the value is '69'
# the type of i is <class 'int'> and the value is '70'
# the type of j is <class 'int'> and the value is '80'
# the type of k is <class 'int'> and the value is '90'
# the type of l is <class 'int'> and the value is '20'
# the type of m is <class 'int'> and the value is '21'
# the type of n is <class 'int'> and the value is '22'
# the type of o is <class 'int'> and the value is '23'
# The type of p is <class 'int'> and the value is '24'
# The type of q is <class 'int'> and the value is '26'
# The type of r is <class 'int'> and the value is '45'
# ...

# %% [markdown]
# # Formatted String Examples of float

# %%
a = 5.6
print(f"the type of a is {type(a)} and value is '{a}'")

b = 6.2
print(f"the type of A is {type(b)} and value is '{b}'")

c = 1.2
print(f"the type of A is {type(c)} and value is '{c}'")

d = 3.0
print(f"the type of A is {type(d)} and value is '{d}'")

e = 4.5
print(f"the type of e is {type(e)} and the value is '{e}'")

f = 5.6
print(f"the type of f is {type(f)} and the value is '{f}'")

g = 8.5
print(f"the type of g is {type(g)} and the value is '{g}' ")

h = 6.9
print(f"the type of h is {type(h)} and the value is '{h}' ")

i = 7.0
print(f"the type of i is {type(i)} and the value is '{i}' ")

j = 8.60
print(f"the type of j is {type(j)} and the value is '{j}'")

k = 9.30
print(f"the type of k is {type(k)} and the value is '{k}' ")

l= 2.20
print(f"the type of l is {type(l)} and the value is '{l}' ")

m = 2.1
print(f"the type of m is {type(m)} and the value is '{m}' ")

n = 2.2
print(f"the type of n is {type(n)} and the value is '{n}' ")

o = 2.3
print(f"the type of o is {type(o)} and the value is '{o}' ")

p = 2.4
print(f"The type of p is {type(p)} and the value is '{p}'")

q = 2.6
print(f"The type of q is {type(q)} and the value is '{q}'")

r = 4.5
print(f"The type of r is {type(r)} and the value is '{r}'")

s = 5.6
print(f"The type of s is {type(s)} and the value is '{s}'")

t = 7.5
print(f"The type of t is {type(t)} and the value is '{t}'")

u = 7.8
print(f"The type of u is {type(u)} and the value is '{u}'")

v = 9.6
print(f"The type of v is {type(v)} and the value is '{v}'")

w = 2.3
print(f"The type of w is {type(w)} and the value is '{w}'")

x = 1.20
print(f"The type of x is {type(x)} and the value is '{x}'")

y = 9.6
print(f"The type of y is {type(y)} and the value is '{y}'")

z = 1.2352
print(f"The type of z is {type(z)} and the value is '{z}'")

temperature_c = 36.6
print(f"The type of temperature_c is {type(temperature_c)} and the value is { temperature_c }")

density = 0.98
print(f"The type of density is {type(density)} and the value is { density }")

interest_rate = 7.25
print(f"The type of interest_rate is {type(interest_rate)} and the value is { interest_rate }")

exchange_rate = 82.65
print(f"The type of exchange_rate is {type(exchange_rate)} and the value is { exchange_rate }")


daily_usage = 1.35
print(f"The type of daily_usage is {type(daily_usage)} and the value is { daily_usage }")

power_kw = 3.6
print(f"The type of power_kw is {type(power_kw)} and the value is { power_kw }")

brightness_lux = 550.2
print(f"The type of brightness_lux is {type(brightness_lux)} and the value is { brightness_lux }")
# Out:
# the type of a is <class 'float'> and value is '5.6'
# the type of A is <class 'float'> and value is '6.2'
# the type of A is <class 'float'> and value is '1.2'
# the type of A is <class 'float'> and value is '3.0'
# the type of e is <class 'float'> and the value is '4.5'
# the type of f is <class 'float'> and the value is '5.6'
# the type of g is <class 'float'> and the value is '8.5'
# the type of h is <class 'float'> and the value is '6.9'
# the type of i is <class 'float'> and the value is '7.0'
# the type of j is <class 'float'> and the value is '8.6'
# the type of k is <class 'float'> and the value is '9.3'
# the type of l is <class 'float'> and the value is '2.2'
# the type of m is <class 'float'> and the value is '2.1'
# the type of n is <class 'float'> and the value is '2.2'
# the type of o is <class 'float'> and the value is '2.3'
# The type of p is <class 'float'> and the value is '2.4'
# The type of q is <class 'float'> and the value is '2.6'
# ...

# %% [markdown]
# # Formatted string Examples of boolean

# %%
is_active = True
print(f"The type of is_active is {type(is_active)} and the value is { is_active }")

has_access = False
print(f"The type of has_access is {type(has_access)} and the value is { has_access }")

is_verified = True
print(f"The type of is_verified is {type(is_verified)} and the value is { is_verified }")

is_admin = False
print(f"The type of is_admin is {type(is_admin)} and the value is { is_admin }")
# Out:
# The type of is_active is <class 'bool'> and the value is True
# The type of has_access is <class 'bool'> and the value is False
# The type of is_verified is <class 'bool'> and the value is True
# The type of is_admin is <class 'bool'> and the value is False

# %% [markdown]
# # Formatted String examples for list

# %%
a = ['apple', 52.8, 'avocado']
print(f"The type of a is {type(a)} and the value is { a }")

b = [1, 2, 3, 4, 5]
print(f"The type of b is {type(b)} and the value is { b }")

c = ['cat', 'camel', 'cow']
print(f"The type of c is {type(c)} and the value is { c }")

d = [199.99, 299.49, 399.0]
print(f"The type of d is {type(d)} and the value is { d }")

e = ['egg', 'eel', 'emu']
print(f"The type of e is {type(e)} and the value is { e }")

f = ['fish', 'frog', 'fox']
print(f"The type of f is {type(f)} and the value is { f }")

g = ['goat', 'gorilla', 'gecko']
print(f"The type of g is {type(g)} and the value is { g }")

h = ['hat', True, True, False, 'hamster']
print(f"The type of h is {type(h)} and the value is { h }")

i = ['ice', 'igloo', 'ink']
print(f"The type of i is {type(i)} and the value is { i }")

j = ['jam', 101, 102, 103]
print(f"The type of j is {type(j)} and the value is { j }")

k = [85, 92, 78, 90, 'kiwi']
print(f"The type of k is {type(k)} and the value is { k }")

l = ['lion', 'leopard', 'llama']
print(f"The type of l is {type(l)} and the value is { l }")

m = ['monkey', 'mouse', 'moose']
print(f"The type of m is {type(m)} and the value is { m }")

n = ['nest', 36.5, 37.0, 38.2]
print(f"The type of n is {type(n)} and the value is { n }")

o = ['orange', 'ostrich', 'owl']
print(f"The type of o is {type(o)} and the value is { o }")

p = ['parrot', 'peacock', 'penguin']
print(f"The type of p is {type(p)} and the value is { p }")

q = ['quail', 'quartz', 'queen']
print(f"The type of q is {type(q)} and the value is { q }")

r = ['rabbit', 'rat', 'rhino']
print(f"The type of r is {type(r)} and the value is { r }")

s = [85, 92, 78, 90]
print(f"The type of s is {type(s)} and the value is { s }")

t = ['tiger', 'turtle', 'turkey']
print(f"The type of t is {type(t)} and the value is { t }")

u = ['umbrella', 'unicorn', 'urchin']
print(f"The type of u is {type(u)} and the value is { u }")

v = ['vulture', 'van', 'vase']
print(f"The type of v is {type(v)} and the value is { v }")

w = ['wolf', 'whale', 'walrus']
print(f"The type of w is {type(w)} and the value is { w }")

x = ['xylophone', 'xerox', 'xenon']
print(f"The type of x is {type(x)} and the value is { x }")

y = ['yak', 'yarn', 'yacht']
print(f"The type of y is {type(y)} and the value is { y }")

z = ['zebra', 'zoo', 'zip']
print(f"The type of z is {type(z)} and the value is { z }")
# Out:
# The type of a is <class 'list'> and the value is ['apple', 52.8, 'avocado']
# The type of b is <class 'list'> and the value is [1, 2, 3, 4, 5]
# The type of c is <class 'list'> and the value is ['cat', 'camel', 'cow']
# The type of d is <class 'list'> and the value is [199.99, 299.49, 399.0]
# The type of e is <class 'list'> and the value is ['egg', 'eel', 'emu']
# The type of f is <class 'list'> and the value is ['fish', 'frog', 'fox']
# The type of g is <class 'list'> and the value is ['goat', 'gorilla', 'gecko']
# The type of h is <class 'list'> and the value is ['hat', True, True, False, 'hamster']
# The type of i is <class 'list'> and the value is ['ice', 'igloo', 'ink']
# The type of j is <class 'list'> and the value is ['jam', 101, 102, 103]
# The type of k is <class 'list'> and the value is [85, 92, 78, 90, 'kiwi']
# The type of l is <class 'list'> and the value is ['lion', 'leopard', 'llama']
# The type of m is <class 'list'> and the value is ['monkey', 'mouse', 'moose']
# ...
